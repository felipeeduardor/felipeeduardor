# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeeduardor/felipeeduardor/blob/main/TRATAMENTO_BASE_DE_DADOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importação de biblioteca
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts

# %%
# importa base de dados
base = pd.read_csv('dados.csv',sep=";")
base.head(10)
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86
# 5      98                  QUARAI  12552.51     381286.24
# 6      95                PIRATINI  10811.67     315884.50
# 7     325                   TUNAS  11543.02     326884.60
# 8     126        SAO LUIZ GONZAGA  15887.14     385185.68
# 9     153              URUGUAIANA  21084.19     401124.62

# %%
# tamanho da base
base.shape
# Out:
# (187, 4)

# %%
# ver valores vazios
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CODIGO        187 non-null    int64
#  1   MUNICIPIO     187 non-null    object
#  2   PIB           187 non-null    float64
#  3   VALOREMPENHO  187 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 6.0+ KB

# %%
# ver as Nan
base.isnull().sum()
# Out:
# CODIGO          0
# MUNICIPIO       0
# PIB             0
# VALOREMPENHO    0
# dtype: int64

# %%
#filtra
agrupado = base.groupby(['CODIGO']).size()
agrupado
# Out:
# CODIGO
# 1      1
# 7      1
# 9      1
# 13     1
# 14     1
#       ..
# 486    1
# 487    1
# 490    1
# 491    1
# 496    1
# Length: 172, dtype: int64

# %%
# padronizando
base['CODIGO'].describe()
# Out:
# count    187.000000
# mean     247.155080
# std      138.750385
# min        1.000000
# 25%      141.000000
# 50%      242.000000
# 75%      372.500000
# max      496.000000
# Name: CODIGO, dtype: float64

# %%
agrupado.plot.bar(color='grey')
# Out:
# <Axes: xlabel='CODIGO'>

# %%
sns.boxplot(base['CODIGO']).set_title('CODIGO')
# Out:
# Text(0.5, 1.0, 'CODIGO')

# %%
sns.distplot(base['CODIGO']).set_title('CODIGO')
# Out:
# <ipython-input-10-896fd264f83c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base['CODIGO']).set_title('CODIGO')
# Text(0.5, 1.0, 'CODIGO')

# %%
sns.barplot(base['CODIGO']).set_title('CODIGO')
# Out:
# Text(0.5, 1.0, 'CODIGO')

# %%
agrupado = base.groupby(['MUNICIPIO']).size()
agrupado
# Out:
# MUNICIPIO
# AGUDO                         1
# AJURICABA                     1
# ALECRIM                       1
# ALMIRANTE TAMANDARE DO SUL    1
# ALTO FELIZ                    1
#                              ..
# VERA CRUZ                     1
# VIADUTOS                      1
# VICTOR GRAEFF                 1
# VILA MARIA                    1
# VILA NOVA DO SUL              1
# Length: 177, dtype: int64

# %%
base['MUNICIPIO'].describe()
# Out:
# count                         187
# unique                        177
# top       SANTA VITORIA DO PALMAR
# freq                            2
# Name: MUNICIPIO, dtype: object

# %%
plt.hist(agrupado, bins=10)
plt.title('MUNICIPIO')
# Out:
# Text(0.5, 1.0, 'MUNICIPIO')

# %%
agrupado = base.groupby(['PIB']).size()
agrupado
# Out:
# PIB
# 8236.63      1
# 9216.87      1
# 10372.80     1
# 10477.52     1
# 10503.72     1
#             ..
# 36739.78     1
# 40671.53     1
# 68672.25     1
# 72353.72     1
# 223848.22    1
# Length: 177, dtype: int64

# %%
base['PIB'].describe()
# Out:
# count       187.000000
# mean      19808.741337
# std       16984.223244
# min        8236.630000
# 25%       13621.455000
# 50%       17206.190000
# 75%       21429.165000
# max      223848.220000
# Name: PIB, dtype: float64

# %%
# VALOREMPENHO

# %%
agrupado = base.groupby(['VALOREMPENHO']).size()
agrupado
# Out:
# VALOREMPENHO
# 172.13        1
# 233.01        1
# 310.58        1
# 365.00        1
# 760.00        4
#              ..
# 485535.86     1
# 533719.86     1
# 800669.92     1
# 1088666.10    1
# 1442759.82    1
# Length: 172, dtype: int64

# %%
base['VALOREMPENHO'].describe()
# Out:
# count    1.870000e+02
# mean     1.299844e+05
# std      1.615491e+05
# min      1.721300e+02
# 25%      5.251718e+04
# 50%      8.422816e+04
# 75%      1.538961e+05
# max      1.442760e+06
# Name: VALOREMPENHO, dtype: float64

# %% [markdown]
# GRAFICOS

# %%
sns.distplot(base['VALOREMPENHO']).set_title('VALOREMPENHO')
# Out:
# <ipython-input-23-e3abfb1089ec>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base['VALOREMPENHO']).set_title('VALOREMPENHO')
# Text(0.5, 1.0, 'VALOREMPENHO')

# %%
X = base.VALOREMPENHO
X
# Out:
# 0      1088666.10
# 1       800669.92
# 2       466122.80
# 3       485535.86
# 4       533719.86
#           ...
# 182        760.00
# 183        365.00
# 184        233.01
# 185        310.58
# 186        172.13
# Name: VALOREMPENHO, Length: 187, dtype: float64

# %%
X.plot.bar(color='green')
# Out:
# <Axes: >

# %%
#VALORDESEMPENHO
sns.boxplot(X)
# Out:
# <Axes: >
